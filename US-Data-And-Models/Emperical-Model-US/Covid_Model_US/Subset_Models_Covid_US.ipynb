# %%
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the Excel file into a pandas dataframe
df_2020 = pd.read_excel('US_2020_Covid19_Data.xlsx', engine='openpyxl')
df_2020 = df_2020.sort_values(by='ISO_START_DATE', ascending = True)
# display(df_2020)

# %%
df_agg = df_2020.groupby(['ISO_YEAR','ISO_START_DATE']).agg({'DAILY_CASES': 'mean'}).reset_index()
#Cleaning the string to not show full date data like time etc.
df_agg['ISO_START_DATE'] = df_agg['ISO_START_DATE'].str.split('T').str[0]
# display(df_agg)

# %% [markdown]
# # US 2020 Covid Cases

# %%
#Create a line plot 
plt.figure(figsize=(16,8))
#Don't know why but the data gets normalized have to divide by 10 to show true numbers
plt.bar(df_agg['ISO_START_DATE'], df_agg['DAILY_CASES']/10, label='Covid Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('US - COVID19 cases 2019')

xtick_pos = np.arange(0, len(df_agg['ISO_START_DATE']), 5)
plt.xticks(xtick_pos, df_agg['ISO_START_DATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# Import the Excel file into a pandas dataframe
df_2021 = pd.read_excel('US_2021_Covid19_Data.xlsx', engine='openpyxl')
df_2021 = df_2021.sort_values(by='ISO_START_DATE', ascending = True)
# display(df_2021)

# %%
df_agg2 = df_2021.groupby(['ISO_YEAR','ISO_START_DATE']).agg({'DAILY_CASES': 'mean'}).reset_index()
#Cleaning the string to not show full date data like time etc.
df_agg2['ISO_START_DATE'] = df_agg2['ISO_START_DATE'].str.split('T').str[0]
# display(df_agg2)

# %% [markdown]
# # US 2021 Covid Cases

# %%
#Create a line plot 
plt.figure(figsize=(16,8))
#Don't know why but the data gets normalized have to divide by 10 to show true numbers
plt.bar(df_agg2['ISO_START_DATE'], df_agg2['DAILY_CASES']/10, label='Covid Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('US - COVID19 cases 2021')

xtick_pos = np.arange(0, len(df_agg2['ISO_START_DATE']), 5)
plt.xticks(xtick_pos, df_agg2['ISO_START_DATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# Import the Excel file into a pandas dataframe
df_2022 = pd.read_excel('US_2022_Covid19_Data.xlsx', engine='openpyxl')
df_2022 = df_2022.sort_values(by='ISO_START_DATE', ascending = True)
# display(df_2022)

# %%
df_agg3 = df_2022.groupby(['ISO_YEAR','ISO_START_DATE']).agg({'DAILY_CASES': 'mean'}).reset_index()
#Cleaning the string to not show full date data like time etc.
df_agg3['ISO_START_DATE'] = df_agg3['ISO_START_DATE'].str.split('T').str[0]
# display(df_agg3)

# %% [markdown]
# # US 2022 Covid Cases

# %%
#Create a line plot 
plt.figure(figsize=(16,8))
#Don't know why but the data gets normalized have to divide by 10 to show true numbers
plt.bar(df_agg3['ISO_START_DATE'], df_agg3['DAILY_CASES']/10, label='Covid Cases')

plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('US - COVID19 cases 2022')

xtick_pos = np.arange(0, len(df_agg3['ISO_START_DATE']), 5)
plt.xticks(xtick_pos, df_agg3['ISO_START_DATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # US 2020 - 2022 Covid Cases

# %%
# Load the data from the Excel file
df_2020_to_2022 = pd.read_excel('US_2020-2022_Covid19_Data.xlsx', engine='openpyxl')
df_agg4 = df_2020_to_2022.groupby(['ISO_YEAR','ISO_START_DATE']).agg({'DAILY_CASES': 'mean'}).reset_index()
df_agg4['ISO_START_DATE'] = df_agg4['ISO_START_DATE'].str.split('T').str[0]
plt.figure(figsize=(16, 6))
plt.bar(df_agg4['ISO_START_DATE'], df_agg4['DAILY_CASES']/10, label='Covid Cases')
plt.xlabel('DATE')
plt.ylabel('Number of Cases')
plt.title('US - COVID19 cases 2020 - 2022')

xtick_pos = np.arange(0, len(df_agg4['ISO_START_DATE']), 5)
plt.xticks(xtick_pos, df_agg4['ISO_START_DATE'][xtick_pos], rotation=45)
plt.legend()
plt.grid()
plt.show()
